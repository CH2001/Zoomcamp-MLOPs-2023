# %%
import wandb

# %% [markdown]
# ### Q1: Wandb version

# %%
print(f"wandb version: {wandb.__version__}")
# Out:
# wandb version: 0.15.3

# %% [markdown]
# ### Q2: Size of DictVectorizer

# %%
# %cd C:\Users\chunh\Downloads\Zoomcamp\Zoomcamp - w2\homework\output
# %ls
# Out:
# C:\Users\chunh\Downloads\Zoomcamp\Zoomcamp - w2\homework\output
#  Volume in drive C is OS
#  Volume Serial Number is AA06-8999
#
#  Directory of C:\Users\chunh\Downloads\Zoomcamp\Zoomcamp - w2\homework\output
#
# 30/05/2023  07:43 PM    <DIR>          .
# 30/05/2023  07:43 PM    <DIR>          ..
# 30/05/2023  07:43 PM           153,660 dv.pkl
# 30/05/2023  07:43 PM         2,632,816 test.pkl
# 30/05/2023  07:43 PM         2,146,162 train.pkl
# 30/05/2023  07:43 PM         2,336,392 valid.pkl
#                4 File(s)      7,269,030 bytes
#                2 Dir(s)  173,962,567,680 bytes free

# %%
print(f'Size of DictVectorizer file is 154 MB')
# Out:
# Size of DictVectorizer file is 154 MB

# %% [markdown]
# ### Q3: Value of max depth

# %% [markdown]
# ![image.png](attachment:07ab9a19-692d-4ea8-b2ad-e2fcd0fcc8f3.png)

# %% [markdown]
# ### Q4: Most important parameter

# %% [markdown]
# ![image.png](attachment:f86e3f4e-3c11-4ffe-9aca-a64bdf0ec5b1.png)

# %% [markdown]
# ### Q5: Model registry

# %% [markdown]
# ![image.png](attachment:1684188c-fe25-4802-a162-ee54c8da07fa.png)
